# %%
import numpy as np
import pandas as pd

# %%
trail = pd.read_csv('/Users/annsarapaul/GitHub/trailrecommender/01 Parsing/trails.csv')

# %%
trail.head(5)
# Out:
#                                                  url                 name  \
# 0    https://www.wta.org/go-hiking/hikes/kelly-butte          Kelly Butte
# 1      https://www.wta.org/go-hiking/hikes/little-si            Little Si
# 2  https://www.wta.org/go-hiking/hikes/45-mile-sh...  45 Mile Sheep Drive
# 3   https://www.wta.org/go-hiking/hikes/lemah-meadow         Lemah Meadow
# 4  https://www.wta.org/go-hiking/hikes/red-top-lo...      Red Top Lookout
#
#                                              region                length  \
# 0      Mount Rainier Area -- Chinook Pass - Hwy 410  3.4 miles, roundtrip
# 1              Snoqualmie Region -- North Bend Area  3.7 miles, roundtrip
# 2  Central Cascades -- Entiat Mountains/Lake Chelan    4.9 miles, one-way
# 3       Snoqualmie Region -- Salmon La Sac/Teanaway    1.0 miles, one-way
# 4       Snoqualmie Region -- Salmon La Sac/Teanaway  1.5 miles, roundtrip
#
#    elevation      hp  currentrating  \
# ...
